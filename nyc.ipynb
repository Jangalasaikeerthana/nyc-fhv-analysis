# %%
#!pip install pandas
# !pip install requests
# Out:
# ...
#      ---------------------------------------- 0.0/41.7 kB ? eta -:--:--
#      --------- ------------------------------ 10.2/41.7 kB ? eta -:--:--
#      ------------------ ------------------- 20.5/41.7 kB 330.3 kB/s eta 0:00:01
#      -------------------------------------  41.0/41.7 kB 330.3 kB/s eta 0:00:01
#      -------------------------------------- 41.7/41.7 kB 289.0 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/73.1 kB ? eta -:--:--
#    ---------------- ----------------------- 30.7/73.1 kB ? eta -:--:--
#    ---------------------------------------- 73.1/73.1 kB 1.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/134.1 kB ? eta -:--:--
#    --------------------------------- ------ 112.6/134.1 kB 6.4 MB/s eta 0:00:01
#    ---------------------------------------- 134.1/134.1 kB 1.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/159.3 kB ? eta -:--:--
# ...

# %%
import pandas as pd
import requests

# %%
url = "https://data.cityofnewyork.us/resource/ywip-y6qr.json?$limit=50000"
# res= requests.get(url)
# data = res.json()
# df = pd.DataFrame(data)
# print(df.head())

# %%
res= requests.get(url)
if res.status_code==200:
    
    data = res.json()
    df = pd.DataFrame(data)
    print(df.head())
else:
    print("Failed to retrieve data. Status code:", res.status_code)
# Out:
#   dispatching_base_num          pickup_datetime         dropoff_datetime  \
# 0               B00001  2023-03-01T00:24:00.000  2023-03-01T02:35:00.000
# 1               B00008  2023-01-01T00:30:00.000  2023-01-01T01:00:00.000
# 2               B00078  2023-01-01T00:01:00.000  2023-01-01T03:15:00.000
# 3               B00111  2023-01-01T00:30:00.000  2023-01-01T01:05:00.000
# 4               B00112  2023-01-01T00:34:45.000  2023-01-01T00:52:03.000
#
#   affiliated_base_number dolocationid pulocationid
# 0                 B00001          NaN          NaN
# 1                 B00008          NaN          NaN
# 2                 B00078          NaN          NaN
# 3                 B03406          NaN          NaN
# 4                 B00112         14.0          NaN
